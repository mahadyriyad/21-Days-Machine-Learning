# %% [markdown]
# Import Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load dataset

# %%
df=pd.read_csv("/content/dataset.csv")
df.head()
# Out:
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000

# %% [markdown]
# Data  Visualization

# %%
plt.xlabel('Area')
plt.ylabel('Price')
plt.scatter(df.area,df.price,color='red',marker='o')

# %% [markdown]
# segregate datase

# %%
x= df.area
x.head()
# Out:
# 0     8450
# 1     9600
# 2    11250
# 3     9550
# 4    14260
# Name: area, dtype: int64

# %%
y=df.price
y.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: price, dtype: int64

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=0)

# %%
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)

# %% [markdown]
# model train

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R² Score:", r2)
# Out:
# MAE: 54521.32050497388
# MSE: 6103023788.979289
# RMSE: 78121.85218605156
# R² Score: 0.07556790220249643

# %%
#Coefficient - m*


m=model.coef_
print(m)

#Intercept - b*"""

b=model.intercept_
print(b)

#Y=mx+b
#*x is Independant variable - Input - area*
#*y is Dependant variable - Output - price*

y = m*x + b
print("The Price of {0} Square feet Land is: {1}".format(x,y[0]))
# Out:
# [2.03409438]
# 159264.76040820673
# The Price of 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: area, Length: 1460, dtype: int64 Square feet Land is: 176452.85791186604

# %%
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, model.predict(x.values.reshape(-1, 1)), color='red', label='Regression Line')
plt.scatter([[x_test]], y_pred, color='green', label='Predicted Point', s=100)
plt.xlabel("Land Area (sq.ft)")
plt.ylabel("Price (lakh taka)")
plt.title("Linear Regression: Land Price Prediction")
plt.legend()
plt.show()

# %%
x=40000
LandAreainSqFt=[[x]]
PredictedmodelResult = model.predict(LandAreainSqFt)
print(PredictedmodelResult)
# Out:
# [240628.53557346]
