# %% [markdown]
# #Data Cleaning

# %% [markdown]
# **How find missing value**

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name": ["John", "Anna", "Mike", "Sara", "Tom"],
    "Age": [28, np.nan, 35, 29, np.nan],
    "Salary": [50000, 60000, np.nan, 58000, 70000]
}
df = pd.DataFrame(data)

df
# Out:
#    Name   Age   Salary
# 0  John  28.0  50000.0
# 1  Anna   NaN  60000.0
# 2  Mike  35.0      NaN
# 3  Sara  29.0  58000.0
# 4   Tom   NaN  70000.0

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       2
# Salary    1
# dtype: int64

# %% [markdown]
# **Method 1: Remove Missing Data**

# %%
df_drop=df.dropna()
df_drop
# Out:
#    Name   Age   Salary
# 0  John  28.0  50000.0
# 3  Sara  29.0  58000.0

# %% [markdown]
# **Method 2: Replace with Constant**

# %%
df_const = df.fillna(0)
df_const
# Out:
#    Name   Age   Salary
# 0  John  28.0  50000.0
# 1  Anna   0.0  60000.0
# 2  Mike  35.0      0.0
# 3  Sara  29.0  58000.0
# 4   Tom   0.0  70000.0

# %% [markdown]
# **Method 3: Replace with Statistical Values**

# %%
df_stat = df.copy()
df_stat['Age'].fillna(df_stat['Age'].mean(), inplace=True)
df_stat['Salary'].fillna(df_stat['Salary'].median(), inplace=True)

df_stat
# Out:
# /tmp/ipython-input-1832501547.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_stat['Age'].fillna(df_stat['Age'].mean(), inplace=True)
# /tmp/ipython-input-1832501547.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_stat['Salary'].fillna(df_stat['Salary'].median(), inplace=True)
#    Name        Age   Salary
# 0  John  28.000000  50000.0
# 1  Anna  30.666667  60000.0
# 2  Mike  35.000000  59000.0
# 3  Sara  29.000000  58000.0
# 4   Tom  30.666667  70000.0

# %% [markdown]
# **Method 4 & 5 Forward / Backward Fill**

# %%
df_ffill = df.fillna(method="ffill")
df_ffill
# Out:
# /tmp/ipython-input-277621521.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method="ffill")
#    Name   Age   Salary
# 0  John  28.0  50000.0
# 1  Anna  28.0  60000.0
# 2  Mike  35.0  60000.0
# 3  Sara  29.0  58000.0
# 4   Tom  29.0  70000.0

# %%
#bacward fill
df_bfill = df.fillna(method="bfill")
df_bfill
# Out:
# /tmp/ipython-input-2735603148.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method="bfill")
#    Name   Age   Salary
# 0  John  28.0  50000.0
# 1  Anna  35.0  60000.0
# 2  Mike  35.0  58000.0
# 3  Sara  29.0  58000.0
# 4   Tom   NaN  70000.0

# %% [markdown]
# **Method 6 : Interpolation**

# %%
df_interp = df.interpolate()
df_interp
# Out:
# /tmp/ipython-input-2017024439.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_interp = df.interpolate()
#    Name   Age   Salary
# 0  John  28.0  50000.0
# 1  Anna  31.5  60000.0
# 2  Mike  35.0  59000.0
# 3  Sara  29.0  58000.0
# 4   Tom  29.0  70000.0

# %% [markdown]
# # Duplicacy Handle

# %% [markdown]
# **How to Check for Duplicates**

# %%
data = {
    "Name": ["John", "Anna", "Mike", "Sara", "John"],
    "Age": [28, 22, 35, 29, 28],
    "City": ["Dhaka", "Chittagong", "Dhaka", "Khulna", "Dhaka"]
}

df = pd.DataFrame(data)
df
# Out:
#    Name  Age        City
# 0  John   28       Dhaka
# 1  Anna   22  Chittagong
# 2  Mike   35       Dhaka
# 3  Sara   29      Khulna
# 4  John   28       Dhaka

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 1

# %% [markdown]
# **Remove All Duplicate Rows**

# %%
df_no_dup = df.drop_duplicates()
df_no_dup
# Out:
#    Name  Age        City
# 0  John   28       Dhaka
# 1  Anna   22  Chittagong
# 2  Mike   35       Dhaka
# 3  Sara   29      Khulna

# %% [markdown]
# **Keep Last Occurrence Instead of First**

# %%
df_keep_last = df.drop_duplicates(keep="last")
df_keep_last
# Out:
#    Name  Age        City
# 1  Anna   22  Chittagong
# 2  Mike   35       Dhaka
# 3  Sara   29      Khulna
# 4  John   28       Dhaka

# %% [markdown]
# **Mark Duplicates Without Removing**

# %%
df["duplicate"] = df.duplicated()
df
# Out:
#    Name  Age        City  duplicate
# 0  John   28       Dhaka      False
# 1  Anna   22  Chittagong      False
# 2  Mike   35       Dhaka      False
# 3  Sara   29      Khulna      False
# 4  John   28       Dhaka       True
